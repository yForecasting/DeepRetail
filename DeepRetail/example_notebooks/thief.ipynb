# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Read and Prepare Data

# %%
# Read data
df = pd.read_csv('/home/filtheo/DeepRetail/DeepRetail/data/data_folder/m5_day.csv', index_col=0)
df.head()
# Out:
#                     2011-01-29  2011-01-30  2011-01-31  2011-02-01  \
# unique_id
# HOBBIES_1_001_CA_1           0           0           0           0
# HOBBIES_1_002_CA_1           0           0           0           0
# HOBBIES_1_003_CA_1           0           0           0           0
# HOBBIES_1_004_CA_1           0           0           0           0
# HOBBIES_1_005_CA_1           0           0           0           0
#
#                     2011-02-02  2011-02-03  2011-02-04  2011-02-05  \
# unique_id
# HOBBIES_1_001_CA_1           0           0           0           0
# HOBBIES_1_002_CA_1           0           0           0           0
# HOBBIES_1_003_CA_1           0           0           0           0
# HOBBIES_1_004_CA_1           0           0           0           0
# HOBBIES_1_005_CA_1           0           0           0           0
#
#                     2011-02-06  2011-02-07  ...  2016-04-15  2016-04-16  \
# unique_id                                   ...
# HOBBIES_1_001_CA_1           0           0  ...           1           3
# HOBBIES_1_002_CA_1           0           0  ...           0           0
# HOBBIES_1_003_CA_1           0           0  ...           2           1
# HOBBIES_1_004_CA_1           0           0  ...           1           0
# HOBBIES_1_005_CA_1           0           0  ...           2           1
#
#                     2016-04-17  2016-04-18  2016-04-19  2016-04-20  \
# unique_id
# HOBBIES_1_001_CA_1           0           1           1           1
# HOBBIES_1_002_CA_1           0           0           0           1
# HOBBIES_1_003_CA_1           2           1           1           1
# HOBBIES_1_004_CA_1           5           4           1           0
# HOBBIES_1_005_CA_1           1           0           1           1
#
#                     2016-04-21  2016-04-22  2016-04-23  2016-04-24
# unique_id
# HOBBIES_1_001_CA_1           3           0           1           1
# HOBBIES_1_002_CA_1           0           0           0           0
# HOBBIES_1_003_CA_1           0           1           1           1
# HOBBIES_1_004_CA_1           1           3           7           2
# HOBBIES_1_005_CA_1           2           2           2           4
#
# [5 rows x 1913 columns]

# %%
# Get the monthly frequency for simplicity
df.columns = pd.to_datetime(df.columns)
df = df.resample('M', axis = 1).sum()

# %%
# Get a small sample
sampled_df = df.sample(3)
sampled_df.head()
# Out:
#                       2011-01-31  2011-02-28  2011-03-31  2011-04-30  \
# unique_id
# HOUSEHOLD_2_355_WI_3           0           3           8           7
# HOUSEHOLD_1_188_CA_4           0           0           0           0
# FOODS_3_127_CA_1              17         113          97         116
#
#                       2011-05-31  2011-06-30  2011-07-31  2011-08-31  \
# unique_id
# HOUSEHOLD_2_355_WI_3           4           9           7           3
# HOUSEHOLD_1_188_CA_4           0           0           0           0
# FOODS_3_127_CA_1             139         126         101          58
#
#                       2011-09-30  2011-10-31  ...  2015-07-31  2015-08-31  \
# unique_id                                     ...
# HOUSEHOLD_2_355_WI_3           6           9  ...          11           5
# HOUSEHOLD_1_188_CA_4          10          14  ...          17          16
# FOODS_3_127_CA_1              76          87  ...         183         123
#
#                       2015-09-30  2015-10-31  2015-11-30  2015-12-31  \
# unique_id
# HOUSEHOLD_2_355_WI_3           4           3           8           5
# HOUSEHOLD_1_188_CA_4          22          17          19          27
# FOODS_3_127_CA_1             113         101          98         136
#
#                       2016-01-31  2016-02-29  2016-03-31  2016-04-30
# unique_id
# HOUSEHOLD_2_355_WI_3           5           4          11           4
# HOUSEHOLD_1_188_CA_4          29          26          28          22
# FOODS_3_127_CA_1              81         102         170         117
#
# [3 rows x 64 columns]

# %% [markdown]
# ##### Use THieF

# %%
from DeepRetail.reconciliation.temporal import THieF
# Out:
# /home/filtheo/DeepRetail/.venv/lib/python3.8/site-packages/statsforecast/core.py:21: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# Define parameters
bottom_level_freq = 'M'
model = 'ETS'

# %% [markdown]
# #### Example 1: No Holdout

# %%
holdout = False
cv = None

# %%
# Define THieF
thief = THieF(bottom_level_freq = bottom_level_freq, holdout = holdout)

# %%
# fit thief
thief.fit(sampled_df, format = 'pivoted')

# %%
# predict base forecasts (also get residuals)
base_fc_1 = thief.predict(model)
res_1 = thief.base_forecast_residuals

# %%
# reconcile
method = 'struc'
rec_fc_1 = thief.reconcile(method = method)

# %%
rec_fc_1.head()
# Out:
#              y             unique_id             Model  temporal_level  fh  \
# 0  1457.657633      FOODS_3_127_CA_1  TR-struc-AutoETS              12   1
# 1   260.147553  HOUSEHOLD_1_188_CA_4  TR-struc-AutoETS              12   1
# 2    67.981082  HOUSEHOLD_2_355_WI_3  TR-struc-AutoETS              12   1
# 3   729.885074      FOODS_3_127_CA_1  TR-struc-AutoETS               6   1
# 4   130.073777  HOUSEHOLD_1_188_CA_4  TR-struc-AutoETS               6   1
#
#         y_base
# 0  1470.000000
# 1   252.000000
# 2    66.000000
# 3   704.006226
# 4   126.195267

# %% [markdown]
# #### Example 2: Holdout & CV

# %%
holdout = True
cv = 3

# %%
# Define THieF
thief = THieF(bottom_level_freq = bottom_level_freq, cv = cv, holdout = holdout)

# fit thief
thief.fit(sampled_df, format = 'pivoted')

# Get base forecasts and residuals
base_fc_2 = thief.predict(model)
res_2 = thief.base_forecast_residuals

# Reconcile base forecasts
# Using mse for reconciliation
method = 'mse'
reconciled_2 = thief.reconcile(method = method)

# %%
reconciled_2.head()
# Out:
#              y             unique_id           Model  temporal_level  fh  \
# 0  1576.884690      FOODS_3_127_CA_1  TR-mse-AutoETS              12   1
# 1   219.677717  HOUSEHOLD_1_188_CA_4  TR-mse-AutoETS              12   1
# 2    86.616381  HOUSEHOLD_2_355_WI_3  TR-mse-AutoETS              12   1
# 3   788.329069      FOODS_3_127_CA_1  TR-mse-AutoETS               6   1
# 4   109.838858  HOUSEHOLD_1_188_CA_4  TR-mse-AutoETS               6   1
#
#         y_base  cv       date  y_true
# 0  1571.000000   1 2014-12-31     NaN
# 1   221.000000   1 2014-12-31     NaN
# 2    83.000000   1 2014-12-31     NaN
# 3   819.993103   1 2015-03-31   823.0
# 4   120.125000   1 2015-03-31   112.0

# %% [markdown]
# ##### Use the Temporal Reconciler

# %%
from DeepRetail.reconciliation.temporal import TemporalReconciler

# %%
# Example 1:
# Reconcile wihtout holdout set
# Reconcile with structural scaling
holdout = False
cv = None

# %%
# Define the TemporalReconciler
temporal_reconciler = TemporalReconciler(bottom_level_freq = bottom_level_freq, holdout = holdout)

# %%
# Fit the reconcilcer
temporal_reconciler.fit(base_fc_1)

# %%
# Reconcile
reconciled = temporal_reconciler.reconcile('struc')

# %%
reconciled.head()
# Out:
#              y             unique_id             Model  temporal_level  fh  \
# 0  1457.657633      FOODS_3_127_CA_1  TR-struc-AutoETS              12   1
# 1   260.147553  HOUSEHOLD_1_188_CA_4  TR-struc-AutoETS              12   1
# 2    67.981082  HOUSEHOLD_2_355_WI_3  TR-struc-AutoETS              12   1
# 3   729.885074      FOODS_3_127_CA_1  TR-struc-AutoETS               6   1
# 4   130.073777  HOUSEHOLD_1_188_CA_4  TR-struc-AutoETS               6   1
#
#         y_base
# 0  1470.000000
# 1   252.000000
# 2    66.000000
# 3   704.006226
# 4   126.195267

# %%
# Example 2:
# Reconcile with a holdout set
# Reconcile using mse
holdout = True
cv = 3

# %%
# Define the TemporalReconciler
temporal_reconciler = TemporalReconciler(bottom_level_freq = bottom_level_freq, holdout = holdout, cv = cv)

# Fit the reconcilcer
temporal_reconciler.fit(base_fc_2)

# Reconcile
reconciled = temporal_reconciler.reconcile('mse', residual_df = res_2)

# %%
reconciled.head()
# Out:
#              y             unique_id           Model  temporal_level  fh  \
# 0  1576.884690      FOODS_3_127_CA_1  TR-mse-AutoETS              12   1
# 1   219.677717  HOUSEHOLD_1_188_CA_4  TR-mse-AutoETS              12   1
# 2    86.616381  HOUSEHOLD_2_355_WI_3  TR-mse-AutoETS              12   1
# 3   788.329069      FOODS_3_127_CA_1  TR-mse-AutoETS               6   1
# 4   109.838858  HOUSEHOLD_1_188_CA_4  TR-mse-AutoETS               6   1
#
#         y_base  cv       date  y_true
# 0  1571.000000   1 2014-12-31     NaN
# 1   221.000000   1 2014-12-31     NaN
# 2    83.000000   1 2014-12-31     NaN
# 3   819.993103   1 2015-03-31   823.0
# 4   120.125000   1 2015-03-31   112.0
