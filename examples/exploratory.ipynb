# %%
# Example for exploratory

# %%
import pandas as pd
from DeepRetail.exploratory import print_summary, visualize_series, get_features, plot_level_volume_variance, zeros_hist, intermittency_classification, CV_zeros_plot

# %%
df = pd.read_csv('.../case_1_month.csv', index_col = 0)

# %%
df.head()
# Out:
#            2019-01-31  2019-02-28  2019-03-31  2019-04-30  2019-05-31  \
# unique_id
# 1009          18850.0     20648.0     22041.0     23122.0     26986.0
# 101           44520.0     41681.0     45700.0     46624.0     46815.0
# 1011          38629.0     39257.0     42932.0     37951.0     35676.0
# 1014          13672.0     13300.0     13841.0     13650.0     13518.0
# 1015          30288.0     29051.0     28708.0     29374.0     20951.0
#
#            2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  ...  \
# unique_id                                                              ...
# 1009          23326.0     18281.0     19221.0     37217.0     28993.0  ...
# 101           35319.0     31760.0     30543.0     42124.0     37121.0  ...
# 1011          40543.0     41726.0     38670.0     45159.0     42209.0  ...
# 1014          19924.0     17061.0     18065.0     15474.0     10269.0  ...
# 1015          37371.0     28236.0     27495.0     28881.0     16952.0  ...
#
# ...

# %%
# Some basic information for the dataframe 
# Will enhance if further
print_summary(df)
# Out:
# A total of 387 items for a total of 39 periods

# %%
# visualize n series and adds moving averages if asked
visualize_series(pivoted_df = df, n = 15, add_moving_average = True, annual = False )

# %%
# plots entropy, seasonality and trend.
# I can add any features asked
get_features(df, seasonal_period = 12, plot = True)
# Out:
#      unique_id   entropy  nperiods  seasonal_period     trend     spike  \
# 0          101       NaN         1               12  0.569355  0.000432
# 1          102  0.890242         1               12  0.130812  0.002678
# 2          104  0.894885         1               12  0.086059  0.003710
# 3          117  0.900896         1               12  0.228402  0.001821
# 4          119       NaN         1               12  0.170494  0.002888
# ..         ...       ...       ...              ...       ...       ...
# 382       6479  0.711914         1               12  0.430636  0.001096
# 383       6497  0.862267         1               12  0.311153  0.000926
# 384       6522  0.844014         1               12  0.242201  0.002340
# 385       6753  0.910724         1               12  0.169476  0.003626
# 386       7434  0.815833         1               12  0.272446  0.001184
#
#      linearity  curvature    e_acf1   e_acf10  seasonal_strength  peak  trough
# ...

# %%
# Returns the level, volume, variance plot
# threshold filter outliers over that value
# Makes it more visually acceptable
plot_level_volume_variance(df, level_threshold=75000)

# %%
zeros_hist(df)

# %%
CV_zeros_plot(df)

# %%
intermittency_classification(df, plot=True)
# Out:
# Smooth: 382
# Erratic: 4
# Intermittent: 1
